# %%
import pandas as pd
df = pd.read_csv('C:/Users/ML/Desktop/122B1F085/AirQuality.csv')

# %%
# Display basic information about the dataset
df.info()

# Display the first few rows
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 9471 entries, ('10/03/2004;18.00.00;2', '6;1360;150;11', '9;1046;166;1056;113;1692;1268;13', '6;48', '9;0') to (';;;;;;;;;;;;;;;;', nan, nan, nan, nan)
# Data columns (total 1 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;  6915 non-null   object
# dtypes: object(1)
# memory usage: 1.2+ MB
#                                                                                                             Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# 10/03/2004;18.00.00;2            6;1360;150;11                 9;1046;166;1056;113;1692;1268;13 6;48 9;0                                                7578;;
# 10/03/2004;19.00.00;2;1292;112;9 4;955;103;1174;92;1559;972;13 3;47                             7;0  7255;;                                                NaN
# 10/03/2004;20.00.00;2            2;1402;88;9                   0;939;131;1140;114;1555;1074;11  9;54 0;0                                                7502;;
# 10/03/2004;21.00.00;2            2;1376;80;9                   2;948;172;1092;122;1584;1203;11  0;60 0;0                                                7867;;
# 10/03/2004;22.00.00;1            6;1272;51;6                   5;836;131;1205;116;1490;1110;11  2;59 6;0                                                7888;;

# %%
print(df.isnull().sum())
# Out:
# Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;    2556
# dtype: int64

# %%
df.isnull()
# Out:
#                                                                                                              Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# 10/03/2004;18.00.00;2            6;1360;150;11                 9;1046;166;1056;113;1692;1268;13 6;48 9;0                                                 False
# 10/03/2004;19.00.00;2;1292;112;9 4;955;103;1174;92;1559;972;13 3;47                             7;0  7255;;                                               True
# 10/03/2004;20.00.00;2            2;1402;88;9                   0;939;131;1140;114;1555;1074;11  9;54 0;0                                                 False
# 10/03/2004;21.00.00;2            2;1376;80;9                   2;948;172;1092;122;1584;1203;11  0;60 0;0                                                 False
# 10/03/2004;22.00.00;1            6;1272;51;6                   5;836;131;1205;116;1490;1110;11  2;59 6;0                                                 False
# ...                                                                                                                                                        ...
# ;;;;;;;;;;;;;;;;                 NaN                           NaN                              NaN  NaN                                                  True
#                                                                                                      NaN                                                  True
#                                                                                                      NaN                                                  True
#                                                                                                      NaN                                                  True
#                                                                                                      NaN                                                  True
#
# [9471 rows x 1 columns]

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;    2556
# dtype: int64

# %%
# Percentage of missing values per column
missing_percentage = df.isnull().mean() * 100
print(missing_percentage)
# Out:
# Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;    26.987646
# dtype: float64

# %%
missing_data = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage': df.isnull().mean() * 100
})

print(missing_data)
# Out:
#                                                     Missing Values  Percentage
# Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);...            2556   26.987646

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize missing values with a heatmap
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')

plt.title("Heatmap of Missing Values")
plt.show()

# %%
# Option 1: Drop rows with any missing values
df.dropna(inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;    0
# dtype: int64

# %%
# Check for duplicates
print(df.duplicated().sum())
# Out:
# 4529

# %%
# Remove duplicates
df_cleaned = df.drop_duplicates(inplace=True)

# %%
# Check for duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.columns)
# Out:
# Index(['Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;'], dtype='object')

# %%
import pandas as pd

# Assuming df is your DataFrame
# Sample DataFrame loading
# df = pd.read_csv('air_quality.csv')

# Filling missing values
for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:  # Check if the column is numeric
        median_value = df[column].median()
        df[column].fillna(median_value, inplace=True)  # Use median for numeric columns

    elif df[column].dtype == 'object':  # Check for categorical columns
        mode_value = df[column].mode()[0]
        df[column].fillna(mode_value, inplace=True)  # Use mode for categorical columns

# Check for remaining missing values
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])  # Only print columns with missing values
# Out:
# Series([], dtype: int64)

# %%
print(df.isnull().sum())
# Out:
# Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;    0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/ML/Desktop/122B1F085/AirQuality.csv')
print(df.describe())  # View summary statistics to spot unusual values
# Out:
#        Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# count                                                6915
# unique                                               4941
# top                                                7487;;
# freq                                                    6

# %%
# Load the dataset with a semicolon delimiter
df = pd.read_csv('C:/Users/ML/Desktop/122B1F085/AirQuality.csv', delimiter=';')
print(df.columns)
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
# Drop unnecessary columns
df = df.drop(columns=['Unnamed: 15', 'Unnamed: 16'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select columns for boxplot (adjust as necessary)
columns_to_plot = ['CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'T', 'RH', 'AH']

# Create boxplots for each selected column
plt.figure(figsize=(12, 8))
df[columns_to_plot].plot(kind='box', subplots=True, layout=(2, 3), figsize=(15, 10), sharey=False)
plt.suptitle("Boxplots for Selected Air Quality Indicators")
plt.show()

# %%
# Plot a single boxplot for 'CO(GT)'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='CO(GT)')
plt.title("Boxplot for CO(GT) Levels")
plt.show()

# %%
# Replace commas with periods in numeric columns
df[numeric_cols] = df[numeric_cols].replace({',': '.'}, regex=True)

# Convert columns to numeric, coercing any problematic values to NaN for easier handling
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Verify changes
print(df[numeric_cols].head())

# Now apply the StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# Check if data is now standardized
print(df[numeric_cols].head())
# Out:
#    CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  \
# 0     2.6       1360.0      11.9         1046.0    166.0        1056.0
# 1     2.0       1292.0       9.4          955.0    103.0        1174.0
# 2     2.2       1402.0       9.0          939.0    131.0        1140.0
# 3     2.2       1376.0       9.2          948.0    172.0        1092.0
# 4     1.6       1272.0       6.5          836.0    131.0        1205.0
#
#    NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# 1     92.0        1559.0        972.0  13.3  47.7  0.7255
# 2    114.0        1555.0       1074.0  11.9  54.0  0.7502
# 3    122.0        1584.0       1203.0  11.0  60.0  0.7867
# 4    116.0        1490.0       1110.0  11.2  59.6  0.7888
#      CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)  \
# 0  0.474000     0.942983  0.242504       0.442297 -0.010166      0.810649
# 1  0.466273     0.736807  0.182085       0.176459 -0.254902      1.177136
# 2  0.468849     1.070327  0.172418       0.129719 -0.146131      1.071538
# 3  0.468849     0.991495  0.177252       0.156010  0.013142      0.922459
# 4  0.461122     0.676167  0.112000      -0.171174 -0.146131      1.273416
#
#     NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)         T        RH        AH
# 0  0.432124      0.643258     0.641101  0.088462  0.183831  0.194881
# 1  0.266684      0.358574    -0.006723  0.081518  0.160400  0.194052
# 2  0.440002      0.350012     0.216513  0.049112  0.283414  0.194686
# 3  0.503027      0.412086     0.498842  0.028279  0.400571  0.195622
# 4  0.455759      0.210881     0.295303  0.032909  0.392761  0.195676

# %%
scaler_minmax = MinMaxScaler()
df_normalized = pd.DataFrame(scaler_minmax.fit_transform(df[numeric_cols]), columns=numeric_cols)

# %%
# Step 3: Log Transformation - apply log transformation to reduce skewness
# Only apply log transformation to positively skewed data, and handle any zero values to avoid math errors
df_log_transformed = df[numeric_cols].apply(lambda x: np.log1p(x) if (x > 0).all() else x)

# %%
# Step 4: Handling Date and Time
# Convert 'Date' and 'Time' to datetime and extract useful components
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], errors='coerce')
df['Year'] = df['DateTime'].dt.year
df['Month'] = df['DateTime'].dt.month
df['Day'] = df['DateTime'].dt.day
df['Hour'] = df['DateTime'].dt.hour
df['DayOfWeek'] = df['DateTime'].dt.dayofweek

# Dropping the original 'Date' and 'Time' columns if no longer needed
df.drop(columns=['Date', 'Time'], inplace=True)

# Output the transformed data to check
print("Standardized Data Sample:")
print(df[numeric_cols].head())

print("\nNormalized Data Sample:")
print(df_normalized.head())

print("\nLog Transformed Data Sample:")
print(df_log_transformed.head())

print("\nDate and Time Components:")
print(df[['DateTime', 'Year', 'Month', 'Day', 'Hour', 'DayOfWeek']].head())
# Out:
# C:\Users\ML\AppData\Local\Temp\ipykernel_5812\2098052719.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], errors='coerce')
# Standardized Data Sample:
#      CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)  \
# 0  0.474000     0.942983  0.242504       0.442297 -0.010166      0.810649
# 1  0.466273     0.736807  0.182085       0.176459 -0.254902      1.177136
# 2  0.468849     1.070327  0.172418       0.129719 -0.146131      1.071538
# 3  0.468849     0.991495  0.177252       0.156010  0.013142      0.922459
# 4  0.461122     0.676167  0.112000      -0.171174 -0.146131      1.273416
#
#     NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)         T        RH        AH
# 0  0.432124      0.643258     0.641101  0.088462  0.183831  0.194881
# 1  0.266684      0.358574    -0.006723  0.081518  0.160400  0.194052
# 2  0.440002      0.350012     0.216513  0.049112  0.283414  0.194686
# 3  0.503027      0.412086     0.498842  0.028279  0.400571  0.195622
# 4  0.455759      0.210881     0.295303  0.032909  0.392761  0.195676
#
# Normalized Data Sample:
#      CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)  \
# 0  0.956111     0.696429  0.803565       0.516156  0.217987      0.435657
# 1  0.953280     0.666071  0.794084       0.478459  0.180465      0.476587
# 2  0.954224     0.715179  0.792567       0.471831  0.197141      0.464794
# 3  0.954224     0.703571  0.793326       0.475559  0.221560      0.448144
# 4  0.951392     0.657143  0.783087       0.429163  0.197141      0.487340
#
#     NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)         T        RH        AH
# 0  0.579630      0.635966     0.539111  0.873262  0.862141  0.992715
# 1  0.540741      0.591261     0.430408  0.872036  0.857984  0.992556
# 2  0.581481      0.589916     0.467866  0.866312  0.879806  0.992678
# 3  0.596296      0.599664     0.515241  0.862633  0.900589  0.992858
# 4  0.585185      0.568067     0.481087  0.863451  0.899203  0.992869
#
# Log Transformed Data Sample:
#      CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)  \
# 0  0.474000     0.942983  0.242504       0.442297 -0.010166      0.810649
# 1  0.466273     0.736807  0.182085       0.176459 -0.254902      1.177136
# 2  0.468849     1.070327  0.172418       0.129719 -0.146131      1.071538
# 3  0.468849     0.991495  0.177252       0.156010  0.013142      0.922459
# 4  0.461122     0.676167  0.112000      -0.171174 -0.146131      1.273416
#
#     NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)         T        RH        AH
# 0  0.432124      0.643258     0.641101  0.088462  0.183831  0.194881
# 1  0.266684      0.358574    -0.006723  0.081518  0.160400  0.194052
# 2  0.440002      0.350012     0.216513  0.049112  0.283414  0.194686
# 3  0.503027      0.412086     0.498842  0.028279  0.400571  0.195622
# 4  0.455759      0.210881     0.295303  0.032909  0.392761  0.195676
#
# Date and Time Components:
#   DateTime  Year  Month  Day  Hour  DayOfWeek
# 0      NaT   NaN    NaN  NaN   NaN        NaN
# 1      NaT   NaN    NaN  NaN   NaN        NaN
# 2      NaT   NaN    NaN  NaN   NaN        NaN
# 3      NaT   NaN    NaN  NaN   NaN        NaN
# 4      NaT   NaN    NaN  NaN   NaN        NaN
